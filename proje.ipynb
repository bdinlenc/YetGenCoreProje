# %%
# %pip install pandas

# %pip install numpy
# %pip install matplotlib
# %pip install seaborn

#kütüphaneler kuruldu

# %%
import pandas as pd

df = pd.read_csv('netflix_titles.csv') #veri seti okundu

df.dropna(inplace=True)
 #eksik veriler silindi



 #açıklaması

# %%
df.columns #satırlarda ne var
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#movieve tv show sayısı
import pandas as pd

df = pd.read_csv("netflix_titles.csv")

# Filmleri ve dizileri saymak için type sütununa göre gruplama yapalım
grouped = df.groupby('type')

# Kaç tane dizi ve kaç tane film olduğunu ekrana yazdıralım
for key, item in grouped:
    print(f"{key} sayısı: {len(item)}")
# Out:
# Movie sayısı: 6131
# TV Show sayısı: 2676

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('netflix_titles.csv')
df_movies = df[df['type'] == 'Movie']
df_tv = df[df['type'] == 'TV Show']

count_movies = df_movies['type'].count()
count_tv = df_tv['type'].count()

labels = ['Movies', 'TV Shows']
counts = [count_movies, count_tv]

plt.figure(figsize=(5, 3))
plt.bar(labels, counts, color=['green', 'blue'])
plt.title('Number of Movies vs TV Shows on Netflix')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %%
df.shape
# Out:
# (5332, 12)

# %%
import seaborn as sns


netflix_movies = df[df['type'] == 'Movie']
plt.figure(figsize=(5,3))
sns.set(style="darkgrid")
ax = sns.countplot(y="release_year", data=netflix_movies, palette=["green", "blue"], 
                   order=netflix_movies['release_year'].value_counts().index[0:10])
ax.set_xlabel('Number of Movies')
ax.set_ylabel('Release Year')
ax.set_title('Number of Movies Released by Year (1o year)')
plt.show()

#son 10 yılda yayınlananlar

# %%
df.describe() #istatiksel analiz özeti çeyreklikler,standart sapma
# Out:
#        release_year
# count   5332.000000
# mean    2012.742123
# std        9.625831
# min     1942.000000
# 25%     2011.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2021.000000

# %%
df.head(10) #ilk on bes satırın gözlemine bakıs
# Out:
#    show_id     type                          title             director
# 7       s8    Movie                        Sankofa         Haile Gerima  \
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
# 27     s28    Movie                      Grown Ups         Dennis Dugan
# 28     s29    Movie                     Dark Skies        Scott Stewart
# 29     s30    Movie                       Paranoia       Robert Luketic
# 38     s39    Movie            Birth of the Dragon         George Nolfi
# 41     s42    Movie                           Jaws     Steven Spielberg
#
#                                                  cast
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...  \
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# 27  Adam Sandler, Kevin James, Chris Rock, David S...
# 28  Keri Russell, Josh Hamilton, J.K. Simmons, Dak...
# 29  Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# 38  Billy Magnussen, Ron Yuan, Qu Jingjing, Terry ...
# 41  Roy Scheider, Robert Shaw, Richard Dreyfuss, L...
#
#                                               country          date_added
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021  \
# 8                                      United Kingdom  September 24, 2021
# 9                                       United States  September 24, 2021
# 12                            Germany, Czech Republic  September 23, 2021
# 24                                              India  September 21, 2021
# 27                                      United States  September 20, 2021
# 28                                      United States  September 19, 2021
# 29                       United States, India, France  September 19, 2021
# 38                       China, Canada, United States  September 16, 2021
# 41                                      United States  September 16, 2021
#
#     release_year rating   duration
# 7           1993  TV-MA    125 min  \
# 8           2021  TV-14  9 Seasons
# 9           2021  PG-13    104 min
# 12          2021  TV-MA    127 min
# 24          1998  TV-14    166 min
# 27          2010  PG-13    103 min
# 28          2013  PG-13     97 min
# 29          2013  PG-13    106 min
# 38          2017  PG-13     96 min
# 41          1975     PG    124 min
#
#                                            listed_in
# 7   Dramas, Independent Movies, International Movies  \
# 8                       British TV Shows, Reality TV
# 9                                   Comedies, Dramas
# 12                      Dramas, International Movies
# 24   Comedies, International Movies, Romantic Movies
# 27                                          Comedies
# 28                   Horror Movies, Sci-Fi & Fantasy
# 29                                         Thrillers
# 38                        Action & Adventure, Dramas
# 41        Action & Adventure, Classic Movies, Dramas
#
#                                           description
# 7   On a photo shoot in Ghana, an American model s...
# 8   A talented batch of amateur bakers face off in...
# 9   A woman adjusting to life after a loss contend...
# 12  After most of her family is murdered in a terr...
# 24  When the father of the man she loves insists t...
# 27  Mourning the loss of their beloved junior high...
# 28  A family’s idyllic suburban life shatters when...
# 29  Blackmailed by his company's CEO, a low-level ...
# 38  A young Bruce Lee angers kung fu traditionalis...
# 41  When an insatiable great white shark terrorize...

# %%
import pandas as pd

# Veri setini oku
df = pd.read_csv('netflix_titles.csv')

# liste oluştur
genre_lists = df['listed_in'].str.split(', ')

# Tüm türleri tek bir liste
all_genres = []
for genre_list in genre_lists:
    all_genres += genre_list
    
# Her türün sayısını say
genre_counts = pd.Series(all_genres).value_counts()

# En çok izlenen 10 türü yazdır
print(genre_counts.head(10))
# Out:
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1351
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    763
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('netflix_titles.csv')

# 'listed_in' sütunundaki her bir türün sayısını hesaplayalım
genre_counts = df['listed_in'].value_counts().head(10)

# Bar grafiğini çizelim
plt.bar(genre_counts.index, genre_counts.values)
plt.xticks(rotation=90)
plt.title('En Çok İzlenen Türler')
plt.xlabel('Tür')
plt.ylabel('Sayı')
plt.show()

# %%
df[(df['type']=='TV Show') & (df['country']=='Turkey')] #Türkiyede yayınlnanların listesi
# Out:
#      show_id     type             title            director
# 3423   s3424  TV Show  Black Money Love      Ahmet Katıksız  \
# 4174   s4175  TV Show          Innocent          Seren Yüce
# 5388   s5389  TV Show                46         Serdar Akar
# 6873   s6874  TV Show             Gonul  Neslihan Yesilyurt
# 7295   s7296  TV Show  Leyla and Mecnun           Onur Ünlü
#
#                                                    cast country
# 3423  Güler Ökten, Hazal Türesan, İlkin Tüfekçi, Bed...  Turkey  \
# 4174  Ali Atay, Haluk Bilginer, Nur Sürer, Okan Yala...  Turkey
# 5388  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey
# 6873           Gökçe Bahadır, Engin Öztürk, Onur Saylak  Turkey
# 7295  Ali Atay, Melis Birkan, Serkan Keskin, Ahmet M...  Turkey
#
#             date_added  release_year rating   duration
# 3423  October 15, 2019          2014  TV-MA   1 Season  \
# 4174  January 23, 2019          2017  TV-MA   1 Season
# 5388      July 1, 2017          2016  TV-MA   1 Season
# 6873     July 12, 2017          2015  TV-14   1 Season
# 7295    April 15, 2017          2014  TV-MA  3 Seasons
#
#                                               listed_in
# 3423  Crime TV Shows, International TV Shows, TV Dramas  \
# 4174  Crime TV Shows, International TV Shows, TV Dramas
# 5388    International TV Shows, TV Dramas, TV Mysteries
# 6873    International TV Shows, TV Dramas, TV Thrillers
# 7295  International TV Shows, Romantic TV Shows, TV ...
#
#                                             description
# 3423  After a cop's fiancée and a jewelry designer's...
# 4174  In a peaceful, rustic town, a retired officer ...
# 5388  A genetics professor experiments with a treatm...
# 6873  A nurse escapes from her surgeon fiancé after ...
# 7295  Destiny brings Mecnun and Leyla together as ne...

# %%
df = pd.read_csv('netflix_titles.csv')

df = df.dropna(subset=['country']) # NaN değerleri çıkar

df_tr = df[df['country'].str.contains('Turkey')] # Türkiye'deki içerikleri filtreleme

top_genres = df_tr['listed_in'].str.split(',').explode().str.strip().value_counts().head(10) # En çok yayınlanan türleri belirleme

# %%
import pandas as pd


df = pd.read_csv('netflix_titles.csv')

# NaN değerlerin çıkarılması

df = df.dropna()

# Türkiye'deki içerikleri filtrelendi

df_tr = df[df['country'].str.contains('Turkey')]

# En çok yayınlanan türleri belirlendi

top_genres = df_tr['listed_in'].str.split(',').explode().str.strip().value_counts().head(10)

print(top_genres)

#türkiyede en cok izlenen on tür
# Out:
# listed_in
# International Movies      78
# Comedies                  56
# Dramas                    29
# Romantic Movies           23
# Action & Adventure         5
# International TV Shows     5
# Horror Movies              4
# TV Dramas                  4
# Thrillers                  3
# Independent Movies         3
# Name: count, dtype: int64

# %%
import pandas as pd

df = pd.read_csv('netflix_titles.csv')

df = df.dropna()  # Eksik değerleri çıkar

df_tr = df[df['country'].str.contains('Turkey')]  # Türkiye'deki içeriklerin filtrelenmesi

top_genres = df_tr['listed_in'].str.split(',').explode().str.strip().value_counts().head(10)

import matplotlib.pyplot as plt #daire grafiği çizilmesi

plt.pie(top_genres.values, labels=top_genres.index)

plt.show()

#trde en cok izlenen turlerin daire grafiği

# %%
import pandas as pd


df = pd.read_csv('netflix_titles.csv')


top_countries = df['country'].str.split(', ', expand=True).stack().value_counts()


top_countries = top_countries.sort_values(ascending=False).head(3)

print(top_countries)



import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('netflix_titles.csv')

# Ülkeleri toplu halde ayırma ve önce büyükten küçüğe sıralama

top_countries = df['country'].str.split(', ', expand=True).stack().value_counts()

# Toplam içerik sayısıyla sıralama

top_countries = top_countries.sort_values(ascending=False).head(3)

# Daire grafiği çizme

plt.pie(top_countries, labels=top_countries.index, autopct='%1.1f%%')
plt.title('Netflix Veri Setinde En Çok İçerik Üreten Ülkeler')
plt.show()
# Out:
# United States     3689
# India             1046
# United Kingdom     804
# Name: count, dtype: int64

# %%
#karar kontrol yapısı olabilir mi random bir sütun seçilip novie ise süresi dizi ise sezonu yazar ama bu cok gerekli bir calısma değil bence

import pandas as pd

# Netflix veri setini yükleme
df = pd.read_csv('netflix_titles.csv')

# Rastgele bir satır seçme
random_row = df.sample()

# type sütunundaki değeri kontrol etme

if random_row['type'].values[0] == 'Movie':
    print('İçerik süresi:', random_row['duration'].values[0])
else:
    print('Bölüm sayısı:', random_row['duration'].values[0])
# Out:
# İçerik süresi: 161 min

# %%
#öneri (girdi aldık ,karar yapısı yaptık)
import random
import pandas as pd

# Netflix veri setini yükleme
df = pd.read_csv('netflix_titles.csv')

# Kullanıcıdan seçim yapmasını isteme
choice = input("Dizi mi yoksa film mi önerilsin? ")

# Sadece filmleri filtrelemek
if choice == "film":
    df_movies = df[df['type'] == 'Movie']
    if not df_movies.empty:
        # Rastgele bir film seçmek
        suggestion = df_movies.sample()
        print("Önerimiz: ")
        print("Film adı:", suggestion['title'].values[0])
        print("Türü:", suggestion['listed_in'].values[0])
        print("Yapım yılı:", suggestion['release_year'].values[0])
        
    else:
        print("Aradığınız kriterlere uygun film bulunamadı.")
        
# Sadece dizileri filtrelemek
elif choice == "dizi":
    df_tv = df[df['type'] == 'TV Show']
    if len(df_tv) > 0:
        # Rastgele bir dizi seçmek
        suggestion = df_tv.sample()
        print("Önerimiz: ")
        print("Dizi adı:", suggestion['title'].values[0])
        print("Türü:", suggestion['listed_in'].values[0])
        print("Yapım yılı:", suggestion['release_year'].values[0])
        
    else:
        print("Aradığınız kriterlere uygun dizi bulunamadı.")
        
# Geçersiz seçim durumu
else:
    print("Lütfen geçerli bir seçim yapın: 'dizi' veya 'film'.")
# Out:
# Önerimiz:
# Dizi adı: Empire Games
# Türü: Docuseries
# Yapım yılı: 2018

# %%
import pandas as pd

# Verileri yükleme
df = pd.read_csv('netflix_titles.csv')

# Sadece film ve TV şovlarını içeren veri setleri oluşturma
df_movies = df[df['type'] == 'Movie']
df_tv_shows = df[df['type'] == 'TV Show']

# Yıla göre gruplayıp toplam sayıları hesaplama
movies_per_year = df_movies.groupby('release_year').size()
tv_shows_per_year = df_tv_shows.groupby('release_year').size()

# En yüksek puanlı filmi bulma ve adını getirme
highest_rated_movies = df_movies.loc[df_movies.groupby('release_year')['rating'].idxmax()][['release_year', 'title']]
highest_rated_movies.set_index('release_year', inplace=True)

# Verileri birleştirme
result = pd.concat([movies_per_year, tv_shows_per_year, highest_rated_movies], axis=1)
result.columns = ['Movies', 'TV Shows', 'Highest Rated Movie']

# Grafik oluşturma
result.plot(kind='bar', figsize=(12,6), color=['green', 'blue', 'purple'])

#hata var ama anlatacağız
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 15
#      12 tv_shows_per_year = df_tv_shows.groupby('release_year').size()
#      14 # En yüksek puanlı filmi bulma ve adını getirme
# ---> 15 highest_rated_movies = df_movies.loc[df_movies.groupby('release_year')['rating'].idxmax()][['release_year', 'title']]
#      16 highest_rated_movies.set_index('release_year', inplace=True)
#      18 # Verileri birleştirme
#
# File c:\Users\drdin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:1086, in SeriesGroupBy.idxmax(self, axis, skipna)
#    1084 @doc(Series.idxmax.__doc__)
#    1085 def idxmax(self, axis: Axis = 0, skipna: bool = True) -> Series:
# -> 1086     result = self._op_via_apply("idxmax", axis=axis, skipna=skipna)
#    1087     return result
#
# File c:\Users\drdin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:981, in GroupBy._op_via_apply(self, name, *args, **kwargs)
#     978     return self.apply(curried)
#     980 is_transform = name in base.transformation_kernels
# --> 981 result = self._python_apply_general(
#     982     curried,
#     983     self._obj_with_exclusions,
#     984     is_transform=is_transform,
#     985     not_indexed_same=not is_transform,
#     986 )
#     988 if self.grouper.has_dropped_na and is_transform:
#     989     # result will have dropped rows due to nans, fill with null
#     990     # and ensure index is ordered same as the input
#     991     result = self._set_result_index_ordered(result)
#
# File c:\Users\drdin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1402, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1367 @final
#    1368 def _python_apply_general(
#    1369     self,
#    (...)
#    1374     is_agg: bool = False,
#    1375 ) -> NDFrameT:
#    1376     """
#    1377     Apply function f in python space
#    1378
#    (...)
#    1400         data after applying f
#    1401     """
# -> 1402     values, mutated = self.grouper.apply(f, data, self.axis)
#    1403     if not_indexed_same is None:
#    1404         not_indexed_same = mutated
#
# File c:\Users\drdin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:767, in BaseGrouper.apply(self, f, data, axis)
#     765 # group might be modified
#     766 group_axes = group.axes
# --> 767 res = f(group)
#     768 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     769     mutated = True
#
# File c:\Users\drdin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:969, in GroupBy._op_via_apply.<locals>.curried(x)
#     968 def curried(x):
# --> 969     return f(x, *args, **kwargs)
#
# File c:\Users\drdin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:2527, in Series.idxmax(self, axis, skipna, *args, **kwargs)
#    2462 """
#    2463 Return the row label of the maximum value.
#    2464
#    (...)
#    2523 nan
#    2524 """
#    2525 # error: Argument 1 to "argmax" of "IndexOpsMixin" has incompatible type
#    2526 # "Union[int, Literal['index', 'columns']]"; expected "Optional[int]"
# -> 2527 i = self.argmax(axis, skipna, *args, **kwargs)  # type: ignore[arg-type]
#    2528 if i == -1:
#    2529     return np.nan
#
# File c:\Users\drdin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:678, in IndexOpsMixin.argmax(self, axis, skipna, *args, **kwargs)
#     674         return delegate.argmax()
#     675 else:
#     676     # error: Incompatible return value type (got "Union[int, ndarray]", expected
#     677     # "int")
# --> 678     return nanops.nanargmax(  # type: ignore[return-value]
#     679         delegate, skipna=skipna
#     680     )
#
# File c:\Users\drdin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:91, in disallow.__call__.<locals>._f(*args, **kwargs)
#      89 if any(self.check(obj) for obj in obj_iter):
#      90     f_name = f.__name__.replace("nan", "")
# ---> 91     raise TypeError(
#      92         f"reduction operation '{f_name}' not allowed for this dtype"
#      93     )
#      94 try:
#      95     with np.errstate(invalid="ignore"):
#
# TypeError: reduction operation 'argmax' not allowed for this dtype
